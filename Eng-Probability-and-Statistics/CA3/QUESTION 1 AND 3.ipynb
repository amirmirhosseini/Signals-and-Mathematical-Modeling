# %% [markdown]
# # Amirmohammad Mirhosseini
# ## 810102601
# ### EPS_CA3 Dr. Vahabie

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
np.random.seed(601)

# %% [markdown]
# # QUESTION 1

# %% [markdown]
# ## 1.1

# %%
poi_distـrate = 10
exp_distـrate = 0.5
geo_distـrate = 0.2

poi_dist_mean = poi_distـrate
poi_dist_var = poi_distـrate

exp_dist_mean = 1/(exp_distـrate)
exp_dist_var = 1/(exp_distـrate*exp_distـrate)

geo_dist_mean = 1/geo_distـrate
geo_dist_var = (1-geo_distـrate)/(geo_distـrate*geo_distـrate)
print('for poi dist, mean is:' , poi_dist_mean, ' var is:' ,poi_dist_var)
print('for exp dist, mean is:' , exp_dist_mean, ' var is:' ,exp_dist_var)
print('for geo dist, mean is:' , geo_dist_mean, ' var is:' ,round(geo_dist_var))
# Out:
# for poi dist, mean is: 10  var is: 10
# for exp dist, mean is: 2.0  var is: 4.0
# for geo dist, mean is: 5.0  var is: 20

# %% [markdown]
# ## 1.2

# %%
sample_size = 30
sampling_count = 1000
# first for s size = 30
# poi , 30
arr = [[] for _ in range(9)]
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

ax1 = axs[0, 0]
means = []
for _ in range(sampling_count):
    #sample = np.random.poisson(poi_distـrate, sample_size)
    sample = []
    for _ in range(sample_size):
        sample.append(np.random.poisson(poi_distـrate))
    sample = np.array(sample)
    sample_mean = np.mean(sample)
    means.append(sample_mean)
ax1.hist(means, bins=80, edgecolor='red', color='black', alpha=1)
ax1.set_xlabel('Mean of Samples')
ax1.set_ylabel('Frequency')
ax1.set_xlim(7.5,12.5)
ax1.set_title(f'Poi Dist (sample_size = 30')
arr[0]=means
ax2=axs[0,1]
means = []
for _ in range(sampling_count):
    #sample = np.random.poisson(poi_distـrate, sample_size)
    sample = []
    for _ in range(sample_size):
        sample.append(np.random.exponential(exp_distـrate))
    sample = np.array(sample)
    sample_mean = np.mean(sample)
    means.append(sample_mean)
ax2.hist(means, bins=80, edgecolor='blue', color='black', alpha=1)
ax2.set_xlabel('Mean of Samples')
ax2.set_xlim(0,1)
ax2.set_ylabel('Frequency')
ax2.set_title(f'Exp Dist (sample_size = 30')
arr[1]=means

ax3=axs[0,2]
means = []
for _ in range(sampling_count):
    #sample = np.random.poisson(poi_distـrate, sample_size)
    sample = []
    for _ in range(sample_size):
        sample.append(np.random.geometric(exp_distـrate))
    sample = np.array(sample)
    sample_mean = np.mean(sample)
    means.append(sample_mean)
ax3.hist(means, bins=80, edgecolor='green', color='black', alpha=1)
ax3.set_xlabel('Mean of Samples')
ax3.set_ylabel('Frequency')
ax3.set_xlim(1,3)
ax3.set_title(f'Geo Dist (sample_size = 30')
arr[2]=means

sample_size = 300

ax1 = axs[1, 0]
means = []
for _ in range(sampling_count):
    #sample = np.random.poisson(poi_distـrate, sample_size)
    sample = []
    for _ in range(sample_size):
        sample.append(np.random.poisson(poi_distـrate))
    sample = np.array(sample)
    sample_mean = np.mean(sample)
    means.append(sample_mean)
ax1.hist(means, bins=80, edgecolor='red', color='black', alpha=1)
ax1.set_xlabel('Mean of Samples')
ax1.set_ylabel('Frequency')
ax1.set_xlim(7.5,12.5)
ax1.set_title(f'Poi Dist (sample_size = 300')
arr[3]=means

ax2=axs[1,1]
means = []
for _ in range(sampling_count):
    #sample = np.random.poisson(poi_distـrate, sample_size)
    sample = []
    for _ in range(sample_size):
        sample.append(np.random.exponential(exp_distـrate))
    sample = np.array(sample)
    sample_mean = np.mean(sample)
    means.append(sample_mean)
ax2.hist(means, bins=80, edgecolor='blue', color='black', alpha=1)
ax2.set_xlabel('Mean of Samples')
ax2.set_ylabel('Frequency')
ax2.set_xlim(0,1)
ax2.set_title(f'Exp Dist (sample_size = 300')
arr[4]=means

ax3=axs[1,2]
means = []
for _ in range(sampling_count):
    #sample = np.random.poisson(poi_distـrate, sample_size)
    sample = []
    for _ in range(sample_size):
        sample.append(np.random.geometric(exp_distـrate))
    sample = np.array(sample)
    sample_mean = np.mean(sample)
    means.append(sample_mean)
ax3.hist(means, bins=80, edgecolor='green', color='black', alpha=1)
ax3.set_xlabel('Mean of Samples')
ax3.set_ylabel('Frequency')
ax3.set_xlim(1,3)
ax3.set_title(f'Geo Dist (sample_size = 300')
arr[5]=means

sample_size=3000

ax1 = axs[2, 0]
means = []
for _ in range(sampling_count):
    #sample = np.random.poisson(poi_distـrate, sample_size)
    sample = []
    for _ in range(sample_size):
        sample.append(np.random.poisson(poi_distـrate))
    sample = np.array(sample)
    sample_mean = np.mean(sample)
    means.append(sample_mean)
ax1.hist(means, bins=80, edgecolor='red', color='black', alpha=1)
ax1.set_xlabel('Mean of Samples')
ax1.set_ylabel('Frequency')
ax1.set_xlim(7.5,12.5)
ax1.set_title(f'Poi Dist (sample_size = 3000')
arr[6]=means

ax2=axs[2,1]
means = []
for _ in range(sampling_count):
    #sample = np.random.poisson(poi_distـrate, sample_size)
    sample = []
    for _ in range(sample_size):
        sample.append(np.random.exponential(exp_distـrate))
    sample = np.array(sample)
    sample_mean = np.mean(sample)
    means.append(sample_mean)
ax2.hist(means, bins=80, edgecolor='blue', color='black', alpha=1)
ax2.set_xlabel('Mean of Samples')
ax2.set_ylabel('Frequency')
ax2.set_xlim(0,1)
ax2.set_title(f'Exp Dist (sample_size = 3000')
arr[7]=means

ax3=axs[2,2]
means = []
for _ in range(sampling_count):
    #sample = np.random.poisson(poi_distـrate, sample_size)
    sample = []
    for _ in range(sample_size):
        sample.append(np.random.geometric(exp_distـrate))
    sample = np.array(sample)
    sample_mean = np.mean(sample)
    means.append(sample_mean)
ax3.hist(means, bins=80, edgecolor='green', color='black', alpha=1)
ax3.set_xlabel('Mean of Samples')
ax3.set_xlim(1,3)
ax3.set_ylabel('Frequency')
ax3.set_title(f'Geo Dist (sample_size = 3000')
arr[8]=means

# %% [markdown]
# ## 1.3

# %%
arrr = np.ndarray((9,2))
for j in [0,1,2]:
    for i in [0,3,6]:
        if i == 0 and j==0:
            print('for poi dist: ')
        if i == 0 and j==1:
            print('for exp dist: ')
        if i==0 and j==2:
            print('for geo dist: ')
        mean_of_means = np.mean(arr[j+i])
        std_of_means = np.std(arr[j+i])
        arrr[i+j,0]=mean_of_means
        arrr[i+j,1]=std_of_means
        print('sample size =', (10**(i/3)*30)  ,'mean is: ', mean_of_means , 'std is: ',std_of_means)
# Out:
# for poi dist:
# sample size = 30.0 mean is:  10.006033333333333 std is:  0.5730292207015082
# sample size = 300.0 mean is:  10.010186666666668 std is:  0.17676987123878823
# sample size = 3000.0 mean is:  10.004370333333334 std is:  0.0579518465615108
# for exp dist:
# sample size = 30.0 mean is:  0.5036989892527237 std is:  0.09315668630229947
# sample size = 300.0 mean is:  0.5004668358716932 std is:  0.027984964692883644
# sample size = 3000.0 mean is:  0.4999689319925628 std is:  0.00889851165905178
# for geo dist:
# sample size = 30.0 mean is:  2.0168 std is:  0.2646506796179111
# sample size = 300.0 mean is:  2.006136666666667 std is:  0.08390257041487002
# sample size = 3000.0 mean is:  1.9994576666666666 std is:  0.02582203165903101

# %% [markdown]
# ### تحلیل:
# با افزایش تعداد نمونه نمودار ها به سمت توزیع نرمال شبیه می‌شوند.
# و بیشتر داده ها در مرکز جمع می‌شوند طبق قضیه حد مرکزی با افزایش سمپل سایز این اتفاق رخ می ‌دهد  واریانس کمتر می‌شود. شبیه تابع ضریبی از تابع دلتای دیراک خواهد شد در سمپل سایز بی نهایت که واریانس به سمت ۰ میل کرده و همه توزیع در خود نقطه میانگین جمع خواهد شد.
# # 1.4

# %%
x = np.linspace(-5, 20, 5000)
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

for i in range(3):
    for j in range(3):
        mean = arrr[3 * i + j,0]
        std = arrr[3 * i + j , 1]
        y = (1/(std * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std) ** 2)
        axs[i, j].plot(x, y)
        axs[i, j].set_title(f'Normal Dist (mean = {mean:.5f}, std = {std:.5f})')
        axs[i, j].set_xlabel('Value')
        axs[i,j].set_xlim(-2,15)
        axs[i, j].set_ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### تحلیل:
# # 1.5
# با افزایش تعداد نمونه میانگین دقیق تر شده و واریانس به سمت ۰ میل می‌کند در هر ۳ توزیع این اتفاق رخ می‌دهد که شبیه به توزیع نرمال و در نهایت با شبیه سازی بیشتر به سمت بی نهایت در نقطه میانگین کل توزیع جمع میشود و شبیه ضریبی از تابع دلتای دیراک خواهد شد..

# %%
MEANS = []
# Set the rates for the distributions


# Randomly select a number between 1 and 3
random_number = np.random.randint(1, 4)
print(f"The randomly selected number is: {random_number}")

#if random_number == 1:
   # means = []
sample_sizes=[30,300,3000]
for sample_size in sample_sizes:
    means=[]
    num_repeats = 1000
    for _ in range(num_repeats):
        samples = np.random.exponential(scale=1/exp_distـrate, size=sample_size)
        means.append(np.mean(samples))
    MEANS.append(means)


if random_number == 1:
    for i in range(3):
        print('Exp dist Mean, when sample size is', sample_size,  'is : ', np.mean(MEANS[i]))
        print('Exp dist Std, when sample size is', sample_size,  'is : ', np.std(MEANS[i]))

#elif random_number == 2:
    
    #sample_size = 3000
   # sample_sizes=[30,300,3000]
for sample_size in sample_sizes:
    num_repeats = 1000
    means = []
    for _ in range(num_repeats):
        samples = np.random.poisson(lam= poi_distـrate, size=sample_size)
        means.append(np.mean(samples))
    MEANS.append(means)

   
if random_number == 2:
    for i in range(3):
        print('Poi dist Mean, when sample size is', sample_size,  'is : ', np.mean(MEANS[3+i]))
        print('Poi dist Std, when sample size is', sample_size,  'is : ', np.std(MEANS[3+i]))



    #sample_size = 3000
  #  sample_sizes=[30,300,3000]
for sample_size in sample_sizes:
    num_repeats = 1000
    means = []
    for _ in range(num_repeats):
        samples = np.random.geometric(p= geo_distـrate, size=sample_size)
        means.append(np.mean(samples))
    MEANS.append(means)

   

if random_number == 3:
    for i in range(3):
        print('Geo dist Mean, when sample size is', sample_size,  'is : ', np.mean(MEANS[6+i]))
        print('Geo dist Std, when sample size is', sample_size,  'is : ', np.std(MEANS[6+i]))

fig, axs = plt.subplots(3, 3, figsize=(15, 15))
for i in range(3):
    #plt.figure(figsize=(10, 6))
    axs[0, i].hist(MEANS[i], bins=60, edgecolor='black', alpha=0.7)
    axs[0, i].set_xlabel('Mean')
    axs[0, i].set_xlim(0,4)
    axs[0, i].set_ylabel('Frequency')
    axs[0, i].set_title(f'Mean Exp Distribution(S_size = {sample_sizes[i]})')
    #axs[0, i].show()
for i in range(3):
    #plt.figure(figsize=(10, 6))
    axs[1, i].hist(MEANS[i+3], bins=60, edgecolor='black', alpha=0.7)
    axs[1, i].set_xlabel('Mean')
    axs[1, i].set_xlim(6,17)
    axs[1, i].set_ylabel('Frequency')
    axs[1, i].set_title(f'Mean Poi Distribution(S_size = {sample_sizes[i]})')
for i in range(3):
    #plt.figure(figsize=(10, 6))
    axs[2, i].hist(MEANS[i+6], bins=60, edgecolor='black', alpha=0.7)
    axs[2, i].set_xlabel('Mean')
    axs[2, i].set_xlim(0,10)
    axs[2, i].set_ylabel('Frequency')
    axs[2, i].set_title(f'Mean Geo Distribution(S_size = {sample_sizes[i]})')
# Out:
# The randomly selected number is: 3
# Geo dist Mean, when sample size is 3000 is :  5.005333333333334
# Geo dist Std, when sample size is 3000 is :  0.8131122650382021
# Geo dist Mean, when sample size is 3000 is :  5.007853333333332
# Geo dist Std, when sample size is 3000 is :  0.2557277037962232
# Geo dist Mean, when sample size is 3000 is :  4.999774333333333
# Geo dist Std, when sample size is 3000 is :  0.08155120182437534

# %% [markdown]
# # 1.6
# ## توجه داشته باشید چون سوال گفته با احتمال یک سوم ابتدا یک عدد برای هر سه توزیع به صورت شانسی اتفاق می‌افتد اگر داده های بقیه توزیع هارا می‌خواهید بررسی کنید لطفا دوباره قسمت پنج و شش را ران کنید.

# %%
print('random number is: ',random_number)
for sample_size in sample_sizes:
    if random_number == 1:
        meansamp = exp_dist_mean
        varsamp = exp_dist_var/sample_size
    if random_number == 2:
        meansamp = poi_dist_mean
        varsamp = poi_dist_var/sample_size
    if random_number == 3:
        meansamp = geo_dist_mean
        varsamp = geo_dist_var/sample_size

    print('by formula, mean is : ', meansamp , " WHEN SAMPLE SIZE IS: ", sample_size)
    print('by formula, var is ', varsamp , " WHEN SAMPLE SIZE IS: ", sample_size)
# Out:
# random number is:  3
# by formula, mean is :  5.0  WHEN SAMPLE SIZE IS:  30
# by formula, var is  0.6666666666666665  WHEN SAMPLE SIZE IS:  30
# by formula, mean is :  5.0  WHEN SAMPLE SIZE IS:  300
# by formula, var is  0.06666666666666665  WHEN SAMPLE SIZE IS:  300
# by formula, mean is :  5.0  WHEN SAMPLE SIZE IS:  3000
# by formula, var is  0.006666666666666665  WHEN SAMPLE SIZE IS:  3000

# %% [markdown]
# بله فرمول میانگین همان میانگین توزیع و واریانس برابر واریانس توزیع تقسیم بر ان که سمپل سایز هست می‌باشد. و اگر مقایسه کنیم نیز برابر است. البته برای واریانس برای سمپل سایز بزرگتر این اتفاق می‌افتد..
# # 1.7

# %%
x = np.linspace(-5, 20, 5000)
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

for i in range(3):
    for j in range(3):
        mean = (np.mean(MEANS[3*i+j]))
        std = (np.std(MEANS[3*i+j]))
        y = (1/(std * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std) ** 2)
        axs[i, j].plot(x, y)
        axs[i, j].set_title(f'Normal Dist (mean = {mean:.4f}, std = {std:.4f})')
        axs[i, j].set_xlabel('Value')
        axs[i, j].set_ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### تحلیل:
# هر چقدر اندازه نمونه‌ها بزرگتر شود، داده‌ها به طور طبیعی به سمت میانگین همگرا می‌شوند و به توزیع نرمال نزدیک‌تر می‌شوند، و واریانس آنها کاهش می‌یابد. این پدیده به قانون اعداد بزرگ و قضیه حد مرکزی مرتبط است.
# قضیه حد مرکزی بیان می‌کند که: اگر تعداد زیادی نمونه تصادفی مستقل از توزیعی که دارای میانگین و واریانس معین باشد، گرفته شود، توزیع مجموع (یا میانگین) این نمونه‌ها به سمت توزیع نرمال میل می‌کند، حتی اگر توزیع اصلی غیر نرمال باشد.
# # QUESTION 3
# ### 3.1

# %%
n = 270
p = 0.3
"""def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)"""
from math import factorial
def comb(n, k):
    return factorial(n) // (factorial(k) * factorial(n - k))

def binomial_prob(n, k, p):
    return comb(n, k) * (p ** k) * ((1 - p) ** (n - k))
x = np.arange(0, n+1)
y = [binomial_prob(n, k, p) for k in x]
x0 = np.arange(30, 141)
y0 = [binomial_prob(n, k, p) for k in x0]
plt.figure(figsize=(10, 6))
plt.bar(x0, y0, color='red' , edgecolor = 'darkred')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlim(30, 140)
plt.show()

# %% [markdown]
# # 3.2

# %%
mean = n * p
std = np.sqrt(n * p * (1 - p))
z = (x - mean)/std
z0 = (x0 - mean)/std

plt.figure(figsize=(15, 9))
plt.bar(z0, y0, color='blue', edgecolor='black', alpha=1)
plt.xlabel('Standardized Value (Z)')
plt.ylabel('Probability')
plt.title(f'Standardized Binomial Distribution (n={n}, p={p})')
plt.xlim(-10, 10) 
plt.show()

# %% [markdown]
# # 3.3

# %%
x1 = np.linspace(-10, 10, 1000)
y1 = (1/(1 * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x1 - 0) / 1) ** 2)

plt.figure(figsize=(15,9))
plt.plot(x1,y1,color='darkred')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title(f'Standardized Normal Distribution')
plt.xlim(-10, 10) 
plt.show()

# %% [markdown]
# ### تحلیل:
# مشاهده می‌گردد که به طور تقریبی با توزیع نرمال استاندارد برابر می‌باشد البته فقط از نظر ظاهری چون مقادیر ایگرگ توزیع نرمال متفاوت می‌باشد
# # 3.4

# %%
total_probability1 = np.sum(y)
total_probability2 = np.sum(y0)
total_probability3 = np.sum(y1)

print('Total probability:', total_probability1)
print('Total probability:', total_probability2)
print('Total probability:', total_probability3)
# Out:
# Total probability: 0.999999999999985
# Total probability: 0.9999999999999286
# Total probability: 49.95000000000002

# %% [markdown]
# ### تحلیل:
# بله به تقریب یک می‌باشد هر دو توزیع بخش ۱ و۲ اما...! توزیع بخش ۳ نرمالایز نمی‌باشد. و انتگرال روی تابع چگالی احتمال آن ۱ نیست.
# # 3.5

# %%
# SIMPLER WAY 
y1_normalized = y1 / np.sum(y1)  
print(np.sum(y1_normalized))

# CORRECT WAY THAT WE ARE ASKED FOR
a = -10  
b = 10  
N = 1000  

dx = (b - a) / N  
x3 = a + np.arange(N) * dx  

y3 = (1/(1 * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x3 - 0) / 1) ** 2)
#print(np.sum(y1))
intapprox = np.sum(y3) 
coef = 1/np.sqrt(270*0.3*(1-0.3))
y_main1_normalized = y3 / intapprox
print(coef)
y_main_normalized = y3 * coef
print(np.sum(y_main_normalized)) 
print('Obtained coefficient:' , coef)
plt.figure(figsize=(15, 9))  
plt.plot(x3, y_main_normalized, color='darkred')  
plt.xlabel('Value')  
plt.ylabel('Normalized Probability')  
plt.title('Normalized Standardized Normal Distribution')  
plt.xlim(-10, 10)  
plt.ylim(0, 0.06)  
plt.show()
# Out:
# 1.0
# 0.13280317881493262
# 6.640158940746632
# Obtained coefficient: 0.13280317881493262

# %% [markdown]
# ### تحلیل:
#  .بله مشکل برطرف می‌شود و نمودار توزیع استاندارد شده با نمودار توزیع نرمال استاندارد شده تقریبا برابر است. برای مقایسه دقت کنید مقادیر وای دو نمودار برابر است برای همین دو نمودار را روی هم نیاز نبود بیندازیم. و اشتراک ایکس هم دارند
# # 3.6

# %%
p=0.5
q=1-p
n=100
k=55
prob = binomial_prob(n,k,p)
print(prob)
m = n * p  
sigma = np.sqrt(n * p * q) 
z = (k - m) / sigma  
prob2 = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * z**2)  
print(prob2)
# Out:
# 0.048474296626430755
# 0.04839414490382868

# %% [markdown]
# # 3.7

# %%
# with simple way

probs=0
for i in range(40,61):
    zs = (i-m) / sigma 
    probs +=  (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * zs**2)  
print(probs)
# Out:
# 0.9645785339057668
